# %%
import pandas as pd

# %%
df_hour = pd.read_csv("hour.csv")
df_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df_day = pd.read_csv("day.csv")
df_day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df_hour.info()
df_hour.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### First operation is mainly  done from the hour dataset because day dataset is providing an overall picture and for details analysis hour dataset is selected.

# %%
df_hour['dteday'] = pd.to_datetime(df_hour['dteday'])

# %%
df_hour.info()
df_hour.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(x='hr',y='cnt', data=df_hour)
plt.title("Hourly Bike Rentals")
plt.show()

# %%
duplicate =  df_hour.duplicated()
print("Total duplicated rows:", duplicate.sum())
# Out:
# Total duplicated rows: 0

# %% [markdown]
# #### Since there is no duplicate in the dataset, we would still ike to check whether the datetime to hour has unique relation or not.

# %%
df_hour[["dteday","hr"]].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### We dont have any duplcate with datetime and hour relation hence all data are unique.

# %%
# Updating the value from 0 to 7 where weekday == 0 i.e. Sunday.
df_hour["weekday"] = df_hour["weekday"].replace(0,7)
print(df_hour["weekday"].unique())
# Out:
# [6 7 1 2 3 4 5]

# %% [markdown]
# # RESET DATAFRAME AS COPY IS MADE HERE -->

# %%
# Creating a copy dataframe so that if require we can revert back to the main dataframe
hour_data_update = df_hour.copy()
hour_data_update.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# For ploting and more clarification a new colum is added as weekday name
# Method : 1
weekday_mapping = {1:"Monday", 2:"Tuesday", 3:"Wednesday", 4:"Thrusday", 5:"Friday", 6:"Saturday", 7:"Sunday"}
hour_data_update["dayName"] = hour_data_update["weekday"].map(weekday_mapping)

# %%
# Method : 2
hour_data_update["dayName"] = hour_data_update["dteday"].dt.day_name()
print(hour_data_update[["dayName","weekday"]].head())
# Out:
#     dayName  weekday
# 0  Saturday        6
# 1  Saturday        6
# 2  Saturday        6
# 3  Saturday        6
# 4  Saturday        6

# %%
# Season and Month mapping
#month_mapping = {1:"January", 2:"February", 3:"March", 4:"April", 5:"May", 6:"June", 7:"July", 8:"August", 9:"September", 10:"October", 11:"November", 12:"December"}
#hour_data_update["monthName"] = hour_data_update["mnth"].map(month_mapping)

hour_data_update["monthName"] = hour_data_update["dteday"].dt.month_name()

season_mapping = {1:"Spring", 2:"Summer", 3:"Fall", 4:"Winter"}
hour_data_update["seasonName"] = hour_data_update["season"].map(season_mapping)

# %%
hour_data_update.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#     dayName monthName seasonName
# 0  Saturday   January     Spring
# 1  Saturday   January     Spring
# 2  Saturday   January     Spring
# 3  Saturday   January     Spring
# 4  Saturday   January     Spring

# %%
hour_data_update["year"] = hour_data_update["dteday"].dt.year

# %%
# dropping index column

if 'instant' in hour_data_update.columns:
    hour_data_update = hour_data_update.drop(columns="instant")

print(hour_data_update.columns)
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt', 'dayName', 'monthName', 'seasonName',
#        'year'],
#       dtype='object')

# %%
hour_data_update.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1   0        0        6           0           1
# 1 2011-01-01       1   0     1   1        0        6           0           1
# 2 2011-01-01       1   0     1   2        0        6           0           1
# 3 2011-01-01       1   0     1   3        0        6           0           1
# 4 2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt   dayName monthName  \
# 0  0.24  0.2879  0.81        0.0       3          13   16  Saturday   January
# 1  0.22  0.2727  0.80        0.0       8          32   40  Saturday   January
# 2  0.22  0.2727  0.80        0.0       5          27   32  Saturday   January
# 3  0.24  0.2879  0.75        0.0       3          10   13  Saturday   January
# 4  0.24  0.2879  0.75        0.0       0           1    1  Saturday   January
#
#   seasonName  year
# 0     Spring  2011
# 1     Spring  2011
# 2     Spring  2011
# 3     Spring  2011
# 4     Spring  2011

# %% [markdown]
# ## Few visualization to understand data more accurately. Using plotly for some interative plots

# %%
# we check season wise bike Usage

import plotly.express as px

season_order = ["Spring", "Summer", "Fall", "Winter"]

fig = px.bar(hour_data_update.groupby("seasonName")["cnt"].sum().reindex(season_order).reset_index(), 
             x="seasonName", y="cnt", title = "Total bike rentals in season", 
             color = "seasonName",color_discrete_sequence = px.colors.qualitative.Set2)

fig.show()

# %%
# Month Wise bike rentals usage

month_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]
month_data = hour_data_update.groupby("monthName")["cnt"].sum().reindex(month_order).reset_index()

fig = px.bar(month_data,x="monthName", y="cnt", title = "Total bike rentals in months", 
             color = "monthName",color_discrete_sequence = px.colors.qualitative.Set2)
fig.show()

# %%
# Hourly bike rental usage

# Average rentals by hour
hour_data = hour_data_update.groupby('hr')['cnt'].mean().reset_index()

fig = px.line(hour_data, x='hr', y='cnt', title="Average Bike Rentals by Hour", markers=True)
fig.update_layout(xaxis_title='Hour (0-23)', yaxis_title='Average Rentals')
fig.show()

# %%
weekday_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
weekday_data = hour_data_update.groupby('dayName')['cnt'].mean().reindex(weekday_order).reset_index()

fig = px.bar(weekday_data,
             x='dayName', y='cnt',
             title="Average Bike Rentals by Weekday",
             color='cnt',
             color_continuous_scale='Plotly3')
fig.show()

# %%
# Average rentals per hour per weather condition only for spring

spring_data = hour_data_update[hour_data_update['seasonName'] == 'Spring']
hour_weather = spring_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()
# Plot
fig = px.line(hour_weather,
              x='hr',
              y='cnt',
              color='weathersit',
              markers=True,
              title="Spring: Hourly Bike Rentals by Weather",
              labels={'hr': 'Hour of Day', 'cnt': 'Average Rentals', 'weathersit': 'Weather Situation'})
fig.show()

# %%
# Average rentals per hour per weather condition only for summer
summer_data = hour_data_update[hour_data_update['seasonName'] == 'Summer']
hour_weather = summer_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()
# Plot
fig = px.line(hour_weather,
              x='hr',
              y='cnt',
              color='weathersit',
              markers=True,
              title="Spring: Hourly Bike Rentals by Weather",
              labels={'hr': 'Hour of Day', 'cnt': 'Average Rentals', 'weathersit': 'Weather Situation'})
fig.show()

# %%
# Average rentals per hour per weather condition only for fall
fall_data = hour_data_update[hour_data_update['seasonName'] == 'Fall']
hour_weather = fall_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()
# Plot
fig = px.line(hour_weather,
              x='hr',
              y='cnt',
              color='weathersit',
              markers=True,
              title="Spring: Hourly Bike Rentals by Weather",
              labels={'hr': 'Hour of Day', 'cnt': 'Average Rentals', 'weathersit': 'Weather Situation'})
fig.show()

# %%
# Average rentals per hour per weather condition only for winter

winter_data = hour_data_update[hour_data_update['seasonName'] == 'Winter']
hour_weather = winter_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()
# Plot
fig = px.line(hour_weather,
              x='hr',
              y='cnt',
              color='weathersit',
              markers=True,
              title="Spring: Hourly Bike Rentals by Weather",
              labels={'hr': 'Hour of Day', 'cnt': 'Average Rentals', 'weathersit': 'Weather Situation'})
fig.show()

# %%
# Let see what do we get when we group season, hour and weathersit
hour_weather_season = hour_data_update.groupby(["seasonName","hr","weathersit"])["cnt"].mean().reset_index()
fig = px.line(hour_weather_season,
              x='hr',
              y='cnt',
              color='weathersit',
              facet_col='seasonName',
              markers=True,
              title="Hourly Bike Rentals by Weather for All Seasons",
              labels={'hr': 'Hour of Day', 'cnt': 'Average Rentals', 'weathersit': 'Weather'},
              facet_col_wrap=2)

fig.update_layout(height=600, width=1000)
fig.show()

# %% [markdown]
# ## Anomaly Detection

# %%
# Boxplot detecting the lower rental periods.
import seaborn as sns
hourly_data = hour_data_update.copy()
left = 0.1
bottom = 0.1
top = 0.8
right = 0.8
fig = plt.figure(figsize=(10,10), dpi=80)
main_ax = plt.axes([left, bottom, right-left, top-bottom])
top_ax = plt.axes([left, top, right-left, 1-top])
plt.axis('off')
main_ax.plot(hourly_data['hr'], hourly_data['cnt'], 'ko', alpha=0.5)
top_ax.boxplot(hourly_data['cnt'], vert=False, notch=True, widths=.6)
plt.show()

# %%
import seaborn as sns
from pyod.utils.utility import standardizer
from pyod.models.iforest import IForest
season_order = ["Spring", "Summer", "Fall", "Winter"]
season_data = (
    hour_data_update.groupby("seasonName")["cnt"]
    .sum()
    .reindex(season_order)
    .reset_index()
)

data_rentals = season_data[["cnt"]].values
X_std = standardizer(data_rentals)

# 25% anomalies as we have 4 seasons, so 1 out of 4
clf = IForest(contamination=0.25, random_state=42)
clf.fit(X_std)

season_data["AnomalyLabel"] = clf.labels_
season_data["AnomalyScore"] = clf.decision_scores_

plt.figure(figsize=(8,5))
sns.lineplot(data=season_data, x="seasonName", y="cnt", marker="o", label="Bike rentals")
# Anomaly detection plot
anomaly = season_data[season_data["AnomalyLabel"] == 1]
plt.scatter(anomaly["seasonName"], anomaly["cnt"], color="red", s=100, label="AnomalyLabel")

plt.title("Total Bike Rentals per Season (with Anomaly Detection)")
plt.ylabel("Total Rentals")
plt.xlabel("Season")
plt.legend()
plt.show()

# %%
#Anomaly detection for month wise bike rentals
month_data = hour_data_update.groupby("monthName")["cnt"].sum().reindex(month_order).reset_index()
data_rentals = month_data[["cnt"]].values
X_std = standardizer(data_rentals)

# 3 months with lowest bike rentals
clf = IForest(contamination=0.25, random_state=42)
clf.fit(X_std)

month_data["AnomalyLabel"] = clf.labels_
month_data["AnomalyScore"] = clf.decision_scores_

plt.figure(figsize=(12,7))
sns.lineplot(data=month_data, x="monthName", y="cnt", marker="o", label="Bike rentals")
# Anomaly detection plot
anomaly = month_data[month_data["AnomalyLabel"] == 1]
plt.scatter(anomaly["monthName"], anomaly["cnt"], color="red", s=100, label="AnomalyLabel")
plt.title("Total Bike Rentals per month")
plt.ylabel("Total Rentals")
plt.xlabel("Month")
plt.legend()
plt.show()

# %%
#Anomaly detection for month wise bike rentals
weekday_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
weekday_data = hour_data_update.groupby('dayName')['cnt'].mean().reindex(weekday_order).reset_index()

data_rentals = weekday_data[["cnt"]].values
X_std = standardizer(data_rentals)

# 3 months with lowest bike rentals
clf = IForest(contamination=0.2, random_state=42)
clf.fit(X_std)

weekday_data["AnomalyLabel"] = clf.labels_
weekday_data["AnomalyScore"] = clf.decision_scores_

plt.figure(figsize=(12,7))
sns.lineplot(data=weekday_data, x="dayName", y="cnt", marker="o", label="Bike rentals")
# Anomaly detection plot
anomaly = weekday_data[weekday_data["AnomalyLabel"] == 1]
plt.scatter(anomaly["dayName"], anomaly["cnt"], color="red", s=100, label="AnomalyLabel")

plt.title("Total Bike Rentals per month")
plt.ylabel("Total Rentals")
plt.xlabel("Month")
plt.legend()
plt.show()

# %%
#Anomaly detection for month wise bike rentals
spring_data = hour_data_update[hour_data_update['seasonName'] == 'Spring']
hour_weather = spring_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()

hour_weather['AnomalyLabel'] = 0

# 3 months with lowest bike rentals
low_rent_threshold = 50
for weather in hour_weather['weathersit'].unique():
    subset = hour_weather[(hour_weather['weathersit'] == weather) & (hour_weather['cnt'] <= low_rent_threshold)]
    
    if len(subset) > 0:
        data_rentals = subset[['cnt']].values
        X_std = standardizer(data_rentals)
        clf = IForest(contamination=0.2, random_state=42)
        clf.fit(X_std)
        hour_weather.loc[subset.index, 'AnomalyLabel'] = clf.labels_

plt.figure(figsize=(10,5))
sns.lineplot(data=hour_weather, x='hr', y='cnt', hue='weathersit', marker='o')
# Anomaly detection plot
anomaly = hour_weather[hour_weather['AnomalyLabel'] == 1]
plt.scatter(anomaly['hr'], anomaly['cnt'], color='red', s=100, label='Anomaly')

plt.title("Hourly Bike Rentals by weather for Spring")
plt.xlabel("Hour of day")
plt.ylabel("avg Rentals")
plt.show()

# %%
#Anomaly detection for month wise bike rentals
summer_data = hour_data_update[hour_data_update['seasonName'] == 'Summer']
hour_weather = summer_data.groupby(['hr', 'weathersit'])['cnt'].mean().reset_index()

hour_weather['AnomalyLabel'] = 0

# 3 months with lowest bike rentals
for weather in hour_weather['weathersit'].unique():
    subset = hour_weather[hour_weather['weathersit'] == weather]
    data_rentals = subset[['cnt']].values
    X_std = standardizer(data_rentals)
    
    clf = IForest(contamination=0.1, random_state=42)
    clf.fit(X_std)
    
    hour_weather.loc[hour_weather['weathersit'] == weather, 'AnomalyLabel'] = clf.labels_

plt.figure(figsize=(10,5))
sns.lineplot(data=hour_weather, x='hr', y='cnt', hue='weathersit', marker='o')
# Anomaly detection plot
anomaly = hour_weather[hour_weather['AnomalyLabel'] == 1]
plt.scatter(anomaly['hr'], anomaly['cnt'], color='red', s=100, label='Anomaly')

plt.title("Hourly Bike Rentals by weather for summer")
plt.xlabel("Hour of day")
plt.ylabel("avg Rentals")
plt.show()

# %% [markdown]
# #### Using PyOD KNN (distance-based)

# %%
from pyod.models.knn import KNN
from pyod.utils.utility import standardizer
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Month-wise rental anomalies
month_order = ["January","February","March","April","May","June","July","August","September","October","November","December"]
month_data = hour_data_update.groupby("monthName")["cnt"].sum().reindex(month_order).reset_index()

# Standardize the data
data_rentals = month_data[["cnt"]].values
X_std = standardizer(data_rentals)

# Fit KNN model
clf = KNN(n_neighbors=5, contamination=0.25)
clf.fit(X_std)

# Add results
month_data["AnomalyLabel"] = clf.labels_
month_data["AnomalyScore"] = clf.decision_scores_

# Plot results
plt.figure(figsize=(12,6))
sns.lineplot(data=month_data, x="monthName", y="cnt", marker="o", label="Bike rentals")
anomaly = month_data[month_data["AnomalyLabel"] == 1]
plt.scatter(anomaly["monthName"], anomaly["cnt"], color="red", s=100, label="Anomaly")
plt.title("Month-wise Bike Rentals (KNN Distance-Based Anomaly Detection)")
plt.xlabel("Month")
plt.ylabel("Total Rentals")
plt.legend()
plt.show()

# %%
from pyod.models.lof import LOF
clf = LOF(contamination=0.25, n_neighbors=10)
clf.fit(X_std)
month_data["AnomalyLabel"] = clf.labels_
month_data["AnomalyScore"] = clf.decision_scores_
# Plot results
plt.figure(figsize=(12,6))
sns.lineplot(data=month_data, x="monthName", y="cnt", marker="o", label="Bike rentals")
anomaly = month_data[month_data["AnomalyLabel"] == 1]
plt.scatter(anomaly["monthName"], anomaly["cnt"], color="red", s=100, label="Anomaly")
plt.title("Month-wise Bike Rentals (LOF Distance-Based Anomaly Detection)")
plt.xlabel("Month")
plt.ylabel("Total Rentals")
plt.legend()
plt.show()

# %% [markdown]
# ### Time- Series Analysis

# %%
# Select only numeric columns before resampling
numeric_cols = hour_data_update.select_dtypes(include='number')

# Perform daily resampling
daily_data = numeric_cols.resample('D').sum()

# Check result
print(daily_data.head())
# Out:
#             season  yr  mnth   hr  holiday  weekday  workingday  weathersit  \
# datetime
# 2011-01-01      24   0    24  276        0      144           0          38
# 2011-01-02      23   0    23  271        0      161           0          45
# 2011-01-03      22   0    22  271        0       22          22          22
# 2011-01-04      23   0    23  273        0       46          23          24
# 2011-01-05      23   0    23  273        0       69          23          23
#
#             temp   atemp    hum  windspeed  casual  registered   cnt   year  \
# datetime
# 2011-01-01  8.26  8.7270  19.34     3.8507     331         654   985  48264
# 2011-01-02  8.36  8.1360  16.01     5.7164     131         670   801  46253
# 2011-01-03  4.32  4.1669   9.62     5.4628     120        1229  1349  44242
# 2011-01-04  4.60  4.8788  13.58     3.6868     108        1454  1562  46253
# 2011-01-05  5.22  5.2732  10.05     4.2987      82        1518  1600  46253
#
#             cluster
# datetime
# 2011-01-01       15
# 2011-01-02       24
# 2011-01-03       34
# 2011-01-04       28
# 2011-01-05       33

# %%
# Ensure the datetime column is properly formatted
hour_data_update['dteday'] = pd.to_datetime(hour_data_update['dteday'])

# Combine date and hour to create a full timestamp if you have 'hr' column
hour_data_update['datetime'] = hour_data_update['dteday'] + pd.to_timedelta(hour_data_update['hr'], unit='h')

# Set datetime as the index
hour_data_update = hour_data_update.set_index('datetime').sort_index()

# %%
print(hour_data_update.index)
print(hour_data_update.head())
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                ...
#                '2012-12-31 14:00:00', '2012-12-31 15:00:00',
#                '2012-12-31 16:00:00', '2012-12-31 17:00:00',
#                '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#                '2012-12-31 20:00:00', '2012-12-31 21:00:00',
#                '2012-12-31 22:00:00', '2012-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=17379, freq=None)
#                         dteday  season  yr  mnth  hr  holiday  weekday  \
# datetime
# 2011-01-01 00:00:00 2011-01-01       1   0     1   0        0        6
# 2011-01-01 01:00:00 2011-01-01       1   0     1   1        0        6
# 2011-01-01 02:00:00 2011-01-01       1   0     1   2        0        6
# 2011-01-01 03:00:00 2011-01-01       1   0     1   3        0        6
# 2011-01-01 04:00:00 2011-01-01       1   0     1   4        0        6
#
#                      workingday  weathersit  temp  ...   hum  windspeed  \
# datetime                                           ...
# 2011-01-01 00:00:00           0           1  0.24  ...  0.81        0.0
# 2011-01-01 01:00:00           0           1  0.22  ...  0.80        0.0
# 2011-01-01 02:00:00           0           1  0.22  ...  0.80        0.0
# 2011-01-01 03:00:00           0           1  0.24  ...  0.75        0.0
# 2011-01-01 04:00:00           0           1  0.24  ...  0.75        0.0
#
#                      casual  registered  cnt   dayName monthName seasonName  \
# datetime
# 2011-01-01 00:00:00       3          13   16  Saturday   January     Spring
# 2011-01-01 01:00:00       8          32   40  Saturday   January     Spring
# 2011-01-01 02:00:00       5          27   32  Saturday   January     Spring
# 2011-01-01 03:00:00       3          10   13  Saturday   January     Spring
# 2011-01-01 04:00:00       0           1    1  Saturday   January     Spring
#
#                      year  cluster
# datetime
# 2011-01-01 00:00:00  2011        1
# 2011-01-01 01:00:00  2011        1
# 2011-01-01 02:00:00  2011        1
# 2011-01-01 03:00:00  2011        1
# 2011-01-01 04:00:00  2011        1
#
# [5 rows x 21 columns]

# %%
# Define aggregation logic for each type of feature
aggregation = {
    'cnt': 'sum',          # total rides per day
    'casual': 'sum',       # total casual users per day
    'registered': 'sum',   # total registered users per day
    'temp': 'mean',        # average temperature per day
    'atemp': 'mean',       # average feeling temperature
    'hum': 'mean',         # average humidity
    'windspeed': 'mean',   # average windspeed
    'season': 'first',     # same within a day
    'weathersit': lambda x: x.mode()[0] if not x.mode().empty else x.iloc[0],  # most common weather
    'weekday': 'first',    # same for all hours in a day
    'mnth': 'first',       # same month
    'yr': 'first'          # same year
}

# Apply aggregation using resample
daily_data = hour_data_update.resample('D').agg(aggregation)

# Check result
print(daily_data.head())
print(daily_data.info())
# Out:
#              cnt  casual  registered      temp     atemp       hum  windspeed  \
# datetime
# 2011-01-01   985     331         654  0.344167  0.363625  0.805833   0.160446
# 2011-01-02   801     131         670  0.363478  0.353739  0.696087   0.248539
# 2011-01-03  1349     120        1229  0.196364  0.189405  0.437273   0.248309
# 2011-01-04  1562     108        1454  0.200000  0.212122  0.590435   0.160296
# 2011-01-05  1600      82        1518  0.226957  0.229270  0.436957   0.186900
#
#             season  weathersit  weekday  mnth  yr
# datetime
# 2011-01-01       1           1        6     1   0
# 2011-01-02       1           2        7     1   0
# 2011-01-03       1           1        1     1   0
# 2011-01-04       1           1        2     1   0
# 2011-01-05       1           1        3     1   0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 731 entries, 2011-01-01 to 2012-12-31
# Freq: D
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cnt         731 non-null    int64
#  1   casual      731 non-null    int64
#  2   registered  731 non-null    int64
#  3   temp        731 non-null    float64
#  4   atemp       731 non-null    float64
#  5   hum         731 non-null    float64
#  6   windspeed   731 non-null    float64
#  7   season      731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   weekday     731 non-null    int64
#  10  mnth        731 non-null    int64
#  11  yr          731 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 74.2 KB
# None

# %%
daily_data['dayofweek'] = daily_data.index.dayofweek + 1
daily_data['month'] = daily_data.index.month
daily_data['year'] = daily_data.index.year

# %%
daily_data.head()
# Out:
#              cnt  casual  registered      temp     atemp       hum  windspeed  \
# datetime
# 2011-01-01   985     331         654  0.344167  0.363625  0.805833   0.160446
# 2011-01-02   801     131         670  0.363478  0.353739  0.696087   0.248539
# 2011-01-03  1349     120        1229  0.196364  0.189405  0.437273   0.248309
# 2011-01-04  1562     108        1454  0.200000  0.212122  0.590435   0.160296
# 2011-01-05  1600      82        1518  0.226957  0.229270  0.436957   0.186900
#
#             season  weathersit  weekday  mnth  yr  dayofweek  month  year
# datetime
# 2011-01-01       1           1        6     1   0          6      1  2011
# 2011-01-02       1           2        7     1   0          7      1  2011
# 2011-01-03       1           1        1     1   0          1      1  2011
# 2011-01-04       1           1        2     1   0          2      1  2011
# 2011-01-05       1           1        3     1   0          3      1  2011

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,5))
sns.lineplot(data=daily_data, x=daily_data.index, y='cnt')
plt.title('Total Daily Bike Rentals Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Rentals')
plt.show()

# %%
daily_data['cnt_7day_avg'] = daily_data['cnt'].rolling(window=7).mean()

plt.figure(figsize=(14,5))
sns.lineplot(data=daily_data, x=daily_data.index, y='cnt', label='Daily Rentals')
sns.lineplot(data=daily_data, x=daily_data.index, y='cnt_7day_avg', label='7-Day Rolling Avg', color='red')
plt.title('Daily Bike Rentals with 7-Day Rolling Average')
plt.xlabel('Date')
plt.ylabel('Number of Rentals')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

decomposition = seasonal_decompose(daily_data['cnt'], model='additive', period=365)
decomposition.plot()
plt.suptitle('Trend, Seasonality, Residual Decomposition – Daily Rentals')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(daily_data['cnt'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
if result[1] <= 0.05:
    print("Series is stationary")
else:
    print("Series is NOT stationary consider differencing")
# Out:
# ADF Statistic: -1.8774481444374298
# p-value: 0.34274344033921944
# Series is NOT stationary consider differencing

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Split train/test (last 30 days as test)
train = daily_data[:-30]
test = daily_data[-30:]

model = SARIMAX(train['cnt'], order=(1,1,1), seasonal_order=(1,1,1,7))
fit_model = model.fit(disp=False)

# Forecast
forecast = fit_model.get_forecast(steps=30)
forecast_ci = forecast.conf_int()

plt.figure(figsize=(10,5))
plt.plot(train.index, train['cnt'], label='Train')
plt.plot(test.index, test['cnt'], label='Test')
plt.plot(forecast.predicted_mean.index, forecast.predicted_mean, label='Forecast')
plt.fill_between(forecast_ci.index,
                 forecast_ci.iloc[:,0],
                 forecast_ci.iloc[:,1], color='gray', alpha=0.2)
plt.legend()
plt.title("SARIMA Forecast - Next 30 Days")
plt.show()

# %%
# Residuals from model
residuals = test['cnt'] - forecast.predicted_mean
threshold = 2 * residuals.std()
anomalies = residuals[abs(residuals) > threshold]

plt.figure(figsize=(10,5))
plt.plot(test.index, residuals, label='Residuals')
plt.scatter(anomalies.index, anomalies.values, color='red', s=80, label='Anomalies')
plt.axhline(y=threshold, color='gray', linestyle='--')
plt.axhline(y=-threshold, color='gray', linestyle='--')
plt.legend()
plt.title("Residual-Based Temporal Anomaly Detection")
plt.show()

# %%
# Load day dataset
day_data = pd.read_csv("day.csv")

# Convert date column to datetime
day_data['dteday'] = pd.to_datetime(day_data['dteday'])

# Set datetime as index for time series operations
day_data = day_data.set_index('dteday').sort_index()

# Quick check
print(day_data.head())
print(day_data.info())
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
# 2011-01-02        2       1   0     1        0        0           0
# 2011-01-03        3       1   0     1        0        1           1
# 2011-01-04        4       1   0     1        0        2           1
# 2011-01-05        5       1   0     1        0        3           1
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
# 2011-01-02           2  0.363478  0.353739  0.696087   0.248539     131
# 2011-01-03           1  0.196364  0.189405  0.437273   0.248309     120
# 2011-01-04           1  0.200000  0.212122  0.590435   0.160296     108
# 2011-01-05           1  0.226957  0.229270  0.436957   0.186900      82
#
#             registered   cnt
# dteday
# 2011-01-01         654   985
# 2011-01-02         670   801
# 2011-01-03        1229  1349
# 2011-01-04        1454  1562
# 2011-01-05        1518  1600
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 731 entries, 2011-01-01 to 2012-12-31
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   season      731 non-null    int64
#  2   yr          731 non-null    int64
#  3   mnth        731 non-null    int64
#  4   holiday     731 non-null    int64
#  5   weekday     731 non-null    int64
#  6   workingday  731 non-null    int64
#  7   weathersit  731 non-null    int64
#  8   temp        731 non-null    float64
#  9   atemp       731 non-null    float64
#  10  hum         731 non-null    float64
#  11  windspeed   731 non-null    float64
#  12  casual      731 non-null    int64
#  13  registered  731 non-null    int64
#  14  cnt         731 non-null    int64
# dtypes: float64(4), int64(11)
# memory usage: 91.4 KB
# None

# %%
import plotly.express as px

# Interactive line plot of daily rentals

day_data['cnt_7day_avg'] = day_data['cnt'].rolling(window=7).mean() 
fig = px.line(
    day_data,
    x=day_data.index,
    y='cnt',
    title='Total Daily Bike Rentals Over Time',
    labels={'dteday': 'Date', 'cnt': 'Number of Rentals'},
    hover_data=['casual', 'registered']  # optional, show casual/registered on hover
)

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Number of Rentals',
    template='plotly_white'
)

fig.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose daily rentals
# period=365 assumes yearly seasonality (365 days)
decomposition = seasonal_decompose(day_data['cnt'], model='additive', period=365)

# Extract components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

fig = go.Figure()

# Original daily rentals
fig.add_trace(go.Scatter(x=day_data.index, y=day_data['cnt'], mode='lines', name='Original'))

# Trend
fig.add_trace(go.Scatter(x=day_data.index, y=trend, mode='lines', name='Trend'))

# Seasonal
fig.add_trace(go.Scatter(x=day_data.index, y=seasonal, mode='lines', name='Seasonal'))

# Residual
fig.add_trace(go.Scatter(x=day_data.index, y=residual, mode='lines', name='Residual'))

fig.update_layout(
    title='Daily Bike Rentals - Seasonal Decomposition',
    xaxis_title='Date',
    yaxis_title='Number of Rentals',
    template='plotly_white'
)

fig.show()

# %%
import numpy as np

threshold = 2 * residual.std()
anomalies = residual[(residual > threshold) | (residual < -threshold)]

# Plot with anomalies
fig = go.Figure()
fig.add_trace(go.Scatter(x=dates, y=day_data['cnt'], mode='lines', name='Original'))
fig.add_trace(go.Scatter(x=anomalies.index, y=day_data.loc[anomalies.index, 'cnt'],
                         mode='markers', marker=dict(color='red', size=8), name='Anomaly'))

fig.update_layout(title='Daily Rentals with Anomalies', xaxis_title='Date', yaxis_title='Rentals')
fig.show()

# %%
from statsmodels.tsa.stattools import adfuller

# Run Augmented Dickey-Fuller test
adf_result = adfuller(day_data['cnt'].dropna())  # drop NaN if trend introduces missing values

print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
print('Critical Values:')
for key, value in adf_result[4].items():
    print(f'\t{key}: {value}')
if adf_result[1] <= 0.05:
    print("The time series is stationary.")
else:
    print("The time series is NOT stationary. Differencing may be needed.")
# Out:
# ADF Statistic: -1.8774481444374298
# p-value: 0.34274344033921944
# Critical Values:
# 	1%: -3.439503230053971
# 	5%: -2.8655794463678346
# 	10%: -2.5689210707289982
# The time series is NOT stationary. Differencing may be needed.

# %%
# First-order differencing
day_data['cnt_diff'] = day_data['cnt'] - day_data['cnt'].shift(1)
# Drop NaN and run ADF again
adf_result_diff = adfuller(day_data['cnt_diff'].dropna())
print('ADF Statistic after differencing:', adf_result_diff[0])
print('p-value after differencing:', adf_result_diff[1])
# Out:
# ADF Statistic after differencing: -11.778809074151846
# p-value after differencing: 1.0467797548021696e-21

# %%
# Train: all days except last 30
train = day_data['cnt'][:-30]
# Test: last 30 days
test = day_data['cnt'][-30:]
print(train.shape, test.shape)
# Out:
# (701,) (30,)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
# SARIMA(p,d,q)(P,D,Q,s)
# p,d,q = AR, differencing, MA for non-seasonal
# P,D,Q,s = seasonal AR, seasonal differencing, seasonal MA, period
# s=7 for weekly seasonality or s=365 for yearly seasonality
model = SARIMAX(train, 
                order=(1,1,1), 
                seasonal_order=(1,1,1,7),  # weekly seasonality
                enforce_stationarity=False,
                enforce_invertibility=False)
fit_model = model.fit(disp=False)
print(fit_model.summary())
# Out:
# c:\Users\basud\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# c:\Users\basud\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                               cnt   No. Observations:                  701
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -5641.386
# Date:                           Sun, 12 Oct 2025   AIC                          11292.772
# Time:                                   22:10:08   BIC                          11315.412
# Sample:                               01-01-2011   HQIC                         11301.533
#                                     - 12-01-2012
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3229      0.037      8.774      0.000       0.251       0.395
# ma.L1         -0.9000      0.021    -42.872      0.000      -0.941      -0.859
# ar.S.L7       -0.0602      0.040     -1.523      0.128      -0.138       0.017
# ma.S.L7       -1.0634      0.019    -55.996      0.000      -1.101      -1.026
# sigma2      7.455e+05   3.65e+04     20.406      0.000    6.74e+05    8.17e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              1053.90
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.99   Skew:                            -1.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast next 30 days
forecast = fit_model.get_forecast(steps=30)
forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int()

# %%
fig = go.Figure()
# Train
fig.add_trace(go.Scatter(x=train.index, y=train, mode='lines', name='Train'))
# Test
fig.add_trace(go.Scatter(x=test.index, y=test, mode='lines', name='Test'))
# Forecast
fig.add_trace(go.Scatter(x=forecast_mean.index, y=forecast_mean, mode='lines', name='Forecast'))
# Confidence interval
fig.add_trace(go.Scatter(
    x=forecast_ci.index.tolist() + forecast_ci.index[::-1].tolist(),
    y=forecast_ci.iloc[:,0].tolist() + forecast_ci.iloc[:,1][::-1].tolist(),
    fill='toself',
    fillcolor='rgba(0,100,80,0.2)',
    line=dict(color='rgba(255,255,255,0)'),
    hoverinfo="skip",
    showlegend=True,
    name='Confidence Interval'
))
fig.update_layout(title='SARIMA Forecast for Daily Bike Rentals',
                  xaxis_title='Date', yaxis_title='Rentals',
                  template='plotly_white')
fig.show()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
# Prepare daily counts
y = day_data['cnt']
# Fit Holt-Winters model
# seasonal='add' for additive seasonality, seasonal_periods=7 for weekly pattern
hw_model = ExponentialSmoothing(y, trend='add', seasonal='add', seasonal_periods=7)
hw_fit = hw_model.fit()
# Forecast next 30 days
forecast = hw_fit.forecast(30)
# Out:
# c:\Users\basud\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.

# %%
fig = go.Figure()
# Original series
fig.add_trace(go.Scatter(x=y.index, y=y, mode='lines', name='Actual'))
# Fitted values
fig.add_trace(go.Scatter(x=y.index, y=hw_fit.fittedvalues, mode='lines', name='Fitted'))
# Forecast
future_dates = pd.date_range(start=y.index[-1] + pd.Timedelta(days=1), periods=30)
fig.add_trace(go.Scatter(x=future_dates, y=forecast, mode='lines', name='Forecast'))
fig.update_layout(title='Holt-Winters Exponential Smoothing Forecast',
                  xaxis_title='Date', yaxis_title='Daily Rentals',
                  template='plotly_white')
fig.show()

# %%
from statsmodels.tsa.ar_model import AutoReg
# Prepare series
y = day_data['cnt']
# Fit AR model (using lag=7 for weekly effect)
ar_model = AutoReg(y, lags=7)
ar_fit = ar_model.fit()
print(ar_fit.summary())
from statsmodels.tsa.ar_model import AutoReg
import pandas as pd
import plotly.graph_objects as go
# Prepare series
y = day_data['cnt']
# Fit AR model (using lag=7 for weekly effect)
ar_model = AutoReg(y, lags=7)
ar_fit = ar_model.fit()
print(ar_fit.summary())
from statsmodels.tsa.ar_model import AutoReg
fig = go.Figure()
# Actual series
fig.add_trace(go.Scatter(x=y.index, y=y, mode='lines', name='Actual'))
# Fitted values
fig.add_trace(go.Scatter(x=y.index, y=ar_fit.fittedvalues, mode='lines', name='Fitted'))
# Forecast
fig.add_trace(go.Scatter(x=future_dates, y=forecast, mode='lines', name='Forecast'))
fig.update_layout(
    title='AutoRegressive (AR) Model Forecast for Daily Bike Rentals',
    xaxis_title='Date',
    yaxis_title='Number of Rentals',
    template='plotly_white'
)
fig.show()
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    cnt   No. Observations:                  731
# Model:                     AutoReg(7)   Log Likelihood               -5976.726
# Method:               Conditional MLE   S.D. of innovations            930.952
# Date:                Sun, 12 Oct 2025   AIC                          11971.451
# Time:                        22:19:45   BIC                          12012.715
# Sample:                    01-08-2011   HQIC                         11987.377
#                          - 12-31-2012
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        237.8586     96.681      2.460      0.014      48.367     427.350
# cnt.L1         0.4962      0.037     13.370      0.000       0.423       0.569
# cnt.L2         0.0673      0.041      1.640      0.101      -0.013       0.148
# cnt.L3         0.0364      0.041      0.887      0.375      -0.044       0.117
# cnt.L4         0.0475      0.041      1.157      0.247      -0.033       0.128
# cnt.L5         0.0737      0.041      1.793      0.073      -0.007       0.154
# cnt.L6         0.1611      0.041      3.911      0.000       0.080       0.242
# cnt.L7         0.0659      0.037      1.770      0.077      -0.007       0.139
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0184           -0.0000j            1.0184           -0.0000
# AR.2            0.7513           -1.0160j            1.2636           -0.1487
# AR.3            0.7513           +1.0160j            1.2636            0.1487
# AR.4           -0.5334           -1.4232j            1.5198           -0.3071
# AR.5           -0.5334           +1.4232j            1.5198            0.3071
# AR.6           -1.9490           -0.4909j            2.0098           -0.4607
# AR.7           -1.9490           +0.4909j            2.0098            0.4607
# -----------------------------------------------------------------------------
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                    cnt   No. Observations:                  731
# Model:                     AutoReg(7)   Log Likelihood               -5976.726
# Method:               Conditional MLE   S.D. of innovations            930.952
# Date:                Sun, 12 Oct 2025   AIC                          11971.451
# Time:                        22:19:45   BIC                          12012.715
# Sample:                    01-08-2011   HQIC                         11987.377
#                          - 12-31-2012
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        237.8586     96.681      2.460      0.014      48.367     427.350
# cnt.L1         0.4962      0.037     13.370      0.000       0.423       0.569
# cnt.L2         0.0673      0.041      1.640      0.101      -0.013       0.148
# cnt.L3         0.0364      0.041      0.887      0.375      -0.044       0.117
# cnt.L4         0.0475      0.041      1.157      0.247      -0.033       0.128
# cnt.L5         0.0737      0.041      1.793      0.073      -0.007       0.154
# cnt.L6         0.1611      0.041      3.911      0.000       0.080       0.242
# cnt.L7         0.0659      0.037      1.770      0.077      -0.007       0.139
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0184           -0.0000j            1.0184           -0.0000
# AR.2            0.7513           -1.0160j            1.2636           -0.1487
# AR.3            0.7513           +1.0160j            1.2636            0.1487
# AR.4           -0.5334           -1.4232j            1.5198           -0.3071
# AR.5           -0.5334           +1.4232j            1.5198            0.3071
# AR.6           -1.9490           -0.4909j            2.0098           -0.4607
# AR.7           -1.9490           +0.4909j            2.0098            0.4607
# -----------------------------------------------------------------------------
# c:\Users\basud\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# c:\Users\basud\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
